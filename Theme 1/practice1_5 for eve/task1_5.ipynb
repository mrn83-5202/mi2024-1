# %% [markdown]
# # Практична робота 1.5
# **Тема:** Основи роботи з VS Code для створення файлів формату `.ipynb` (Markdown + Code Cells) + Базовий Python
# **Мета:**
# - Навчитися створювати та редагувати Jupyter Notebook у VS Code.
# - Опрацювати можливості Markdown-розмітки.
# - Ознайомитися з базовими конструкціями мови програмування Python.
# - Зберегти робочу версію файлу в особистому GitHub-репозиторії у папці `practice_1_5`.

# %% [markdown]
# ## Крок 1. Підготовка робочого середовища
#
# 1. Відкрийте VS Code (за потреби встановіть необхідні розширення: Jupyter та Python).
# 2. Створіть новий файл Jupyter Notebook (Файл > New File... > Jupyter Notebook).
# 3. Збережіть його під назвою `practice_1_5.ipynb`.

# %% [markdown]
# ## Крок 2. Робота з Markdown у Jupyter Notebook
#
# ### Завдання 2.1
#
# 1. Створіть нову комірку з типом **Markdown**.
# 2. Додайте до неї інформацію про себе (ім’я, групу, email).
# 3. Використайте хоча б один заголовок (наприклад, `#` або `##`) і хоча б один елемент списку (нумерований або маркований).
#
# > **Підказка щодо розмітки:**
# > - Заголовок: `# Заголовок`, `## Підзаголовок`, …
# > - Списки:
# >   - Маркований: `- Пункт` або `* Пункт`
# >   - Нумерований: `1. Пункт`, `2. Пункт`

# %% [markdown]
# ## Крок 3. Робота з code cells (Python)
#
# У Jupyter Notebook, окрім тексту (Markdown), можна виконувати код (Python, R та ін.) у окремих комірках (Code cells).
#
# ### Завдання 3.1
#
# 1. Створіть нову комірку з типом **Code**.
# 2. Напишіть Python-код, який виводить привітання, наприклад:
#
# ```python
# print("Привіт, це моя перша робота з Jupyter Notebook у VS Code!")
# ```
#
# 3. Запустіть комірку та переконайтеся, що результат з’являється під нею.

# %% [markdown]
# ## Крок 4. Основи Python: змінні, типи даних, введення/виведення
#
# ### Завдання 4.1. Змінні та типи даних
#
# 1. Створіть нову комірку **Code**.
# 2. Оголосіть декілька змінних різних типів: рядок (str), ціле число (int), дійсне число (float) і логічне значення (bool).
# 3. Виведіть їх на екран за допомогою функції `print()`.
# 4. Перевірте та виведіть тип кожної змінної за допомогою функції `type()`.
#
# **Приклад коду:**
#
# ```python
# name = "Petro"  # str
# age = 20        # int
# height = 1.75   # float
# is_student = True  # bool
#
# print(name, age, height, is_student)
# print(type(name), type(age), type(height), type(is_student))
# ```

# %% [markdown]
# ### Завдання 4.2. Введення даних та кастинг (перетворення типів)
#
# 1. Створіть нову комірку **Code**.
# 2. Зчитайте від користувача ціле число за допомогою `input()` та функції `int()`.
# 3. Обчисліть і виведіть результат (наприклад, значення числа, помноженого на 2).
#
# ```python
# user_input = input("Введіть ціле число: ")
# number = int(user_input)  # перетворюємо з рядка у ціле
# result = number * 2
# print(f"Результат множення {number} на 2: {result}")
# ```

# %% [markdown]
# ## Крок 5. Основи Python: розгалуження (if/else) та цикли
#
# ### Завдання 5.1. Умовні оператори
#
# 1. Створіть нову комірку **Code**.
# 2. Запитайте у користувача його вік.
# 3. Якщо вік менше 18 — виведіть повідомлення, що користувач ще неповнолітній; інакше — привітайте зі статусом повнолітньої особи.
#
# **Приклад коду:**
#
# ```python
# age = int(input("Введіть ваш вік: "))
# if age < 18:
#     print("Ви ще неповнолітній.")
# else:
#     print("Вітаємо! Ви повнолітній.")
# ```

# %% [markdown]
# ### Завдання 5.2. Цикли
#
# 1. Створіть нову комірку **Code**.
# 2. За допомогою циклу `for` виведіть всі числа від 1 до n+10, де n - Ваш номер у списку в журналі.
# 3. За допомогою циклу `while` виведіть всі числа від n+10 до 1.
#
# **Приклад коду для for-циклу:**
#
# ```python
# for i in range(1, 6):
#     print(i)
# ```
#
# **Приклад коду для while-циклу:**
#
# ```python
# j = 5
# while j >= 1:
#     print(j)
#     j -= 1
# ```

# %% [markdown]
# ## Крок 6. Додаткове завдання
#
# Спробуйте реалізувати просту програму-калькулятор, яка вміє виконувати 4 операції: додавання, віднімання, множення та ділення.
#
# **Приклад алгоритму:**
# 1. Запитайте у користувача два числа.
# 2. Запитайте, яку операцію бажає виконати користувач: `+`, `-`, `*` чи `/`.
# 3. Залежно від вибраної операції виконайте дію і виведіть результат.
# 4. Опрацюйте випадок ділення на нуль.
#
# ```python
# print("Простий калькулятор")
#
# num1 = float(input("Введіть перше число: "))
# num2 = float(input("Введіть друге число: "))
# operation = input("Оберіть операцію (+, -, *, /): ")
#
# if operation == "+":
#     result = num1 + num2
# elif operation == "-":
#     result = num1 - num2
# elif operation == "*":
#     result = num1 * num2
# elif operation == "/":
#     if num2 == 0:
#         result = "Помилка: ділення на нуль!"
#     else:
#         result = num1 / num2
# else:
#     result = "Невідома операція!"
#
# print("Результат:", result)
# ```

# %% [markdown]
# ## Крок 7. Збереження та завантаження у GitHub
#
# 1. Збережіть файл **`practice_1_5.ipynb`**.
# 2. Якщо у вас ще немає локального репозиторію, створіть його будь-яким зручним способом (VS Code, Git Bash тощо) та зв’яжіть з вашим GitHub-репозиторієм.
# 3. Створіть у репозиторії папку **`practice_1_5`** (якщо ще не створена).
# 4. Перенесіть файл `practice_1_5.ipynb` до цієї папки, додайте до індексу, виконайте коміт (commit) та відправте зміни (push) у свій GitHub-репозиторій.
#
# > **Приклад команд Git (з терміналу VS Code чи Git Bash):**
# > ```bash
# > git add .
# > git commit -m "Add practice_1_5 notebook with Python basics"
# > git push
# > ```
#
# 5. Перевірте на GitHub, чи з’явився ваш файл **`practice_1_5.ipynb`** у папці **`practice_1_5`**.

# %% [markdown]
# ## Крок 8. Висновки
#
# У кінці файлу додайте короткий висновок:
# - Які основні можливості Markdown ви спробували?
# - Як зручно запускати Python-код у Code Cells?
# - Що нового дізналися про базові конструкції Python (змінні, типи, умовні оператори, цикли)?
# - Чи виникали труднощі при завантаженні в GitHub?
#
# Ще раз оновіть репозиторій на GitHub.

# %% [markdown]
# ### Результат
#
# Після виконання всіх пунктів у вас має бути:
# 1. Створений та заповнений файл **`practice_1_5.ipynb`** із демонстрацією Markdown та кількома фрагментами коду Python (змінні, введення/виведення, умови, цикли).
# 2. Завантажений (опублікований) файл у вашому репозиторії GitHub у папці **`practice_1_5`**.
#
# На цьому практична робота вважається виконаною.

# %% [markdown]
# ### Як користуватися цим шаблоном?
# 1. Скопіюйте наведений текст у свій новостворений `.ipynb`-файл (у VS Code можна скопіювати все разом в Markdown/Code Cells або додавати поступово).
# 2. Дотримуйтесь інструкцій кожного кроку, виконайте завдання з базових елементів Python.
# 3. Збережіть, закомітьте і відправте зміни у GitHub.
#
# **Успіхів у виконанні!**
