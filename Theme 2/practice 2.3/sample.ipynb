# %%
# %pip install requests bs4 pandas
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 3.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/11.5 MB 2.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.5 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.5 MB 2.0 MB/s eta 0:00:06
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL сторінки новин КНУ
url = "https://knu.ua/news"

# Виконання запиту на сайт
response = requests.get(url)
response.encoding = 'utf-8'  # Встановлення кодування для коректного відображення українських символів

# Перевірка статусу відповіді
if response.status_code == 200:
    # Створення об'єкта BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Пошук всіх елементів, що містять заголовки новин
    headlines = []
    for item in soup.find_all('a', class_='b-menu__link'):
        title = item.get_text(strip=True)
        headlines.append({'Заголовок': title})
    
    # Створення DataFrame для збереження заголовків
    df = pd.DataFrame(headlines)
    
    # Збереження у CSV-файл
    df.to_csv('knu_headlines.csv', index=False, encoding='utf-8')
    print("Заголовки збережено у файл knu_headlines.csv")
else:
    print(f"Не вдалося отримати доступ до сайту. Статус код: {response.status_code}")
# Out:
# Заголовки збережено у файл knu_headlines.csv

# %%
# %pip install openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (c:\MIAZ2024\mi2024\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\MIAZ2024\mi2024\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\MIAZ2024\mi2024\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\MIAZ2024\mi2024\.venv\Lib\site-packages)
# ...

# %%
import pandas as pd
from datetime import datetime, timedelta

# Generate sample data for Excel
periods = 2

data = {
    "Date": pd.date_range(start="2024-09-01", periods=periods, freq="D"),
    "Value": [round(1000 * (1 + 0.01 * i)) for i in range(periods)]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save to an Excel file
file_path = 'sample_data2.xlsx'
df.to_excel(file_path, index=False)

file_path
# Out:
# 'sample_data2.xlsx'

# %%
import xml.etree.ElementTree as ET

# Дані про підрозділи
units = [
    {"name": "Alpha", "quantity": 100, "status": "Active"},
    {"name": "Bravo", "quantity": 80, "status": "Inactive"},
    {"name": "Charlie", "quantity": 120, "status": "Active"},
]

# Створення кореневого елемента
root = ET.Element("Units")

# Додавання підрозділів до XML
for unit in units:
    unit_element = ET.SubElement(root, "Unit")
    
    name_element = ET.SubElement(unit_element, "Name")
    name_element.text = unit["name"]
    
    quantity_element = ET.SubElement(unit_element, "Quantity")
    quantity_element.text = str(unit["quantity"])
    
    status_element = ET.SubElement(unit_element, "Status")
    status_element.text = unit["status"]

# Створення дерева та збереження у файл
tree = ET.ElementTree(root)
tree.write("units.xml", encoding="utf-8", xml_declaration=True)

print("XML-файл створено: units.xml")
# Out:
# XML-файл створено: units.xml
